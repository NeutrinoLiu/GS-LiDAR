# %%
import json
import yaml
import numpy as np
import os
import re

base_dir = os.path.join("data", "opv2v")

mode = "test"
mode_transform = "test_transform"

os.makedirs(os.path.join(base_dir, mode_transform), exist_ok=True)

def rotation_matrix(roll, yaw, pitch):
    R = np.array([[np.cos(yaw)*np.cos(pitch), 
                   np.cos(yaw)*np.sin(pitch)*np.sin(roll)-np.sin(yaw)*np.cos(roll), 
                   np.cos(yaw)*np.sin(pitch)*np.cos(roll)+np.sin(yaw)*np.sin(roll)],
                  [np.sin(yaw)*np.cos(pitch), 
                   np.sin(yaw)*np.sin(pitch)*np.sin(roll)+np.cos(yaw)*np.cos(roll), 
                   np.sin(yaw)*np.sin(pitch)*np.cos(roll)-np.cos(yaw)*np.sin(roll)],
                  [-np.sin(pitch), 
                   np.cos(pitch)*np.sin(roll), 
                   np.cos(pitch)*np.cos(roll)]])
    return R

def get_c2w_matrix(calib):
    R = rotation_matrix(*(np.array(calib["lidar_pose"][3:]) * np.pi / 180))
    
    translation_vector = np.array(calib["lidar_pose"][:3])
    
    c2w_matrix = np.eye(4)
    c2w_matrix[:3, :3] = R
    c2w_matrix[:3, 3] = translation_vector
    
    return c2w_matrix

for scenario in os.listdir(os.path.join(base_dir, mode)):
    os.makedirs(os.path.join(base_dir, mode_transform, scenario), exist_ok=True)
    for vehicle in os.listdir(os.path.join(base_dir, mode, scenario)):
        if vehicle.endswith(".yaml"):
            continue
        else:
            resulted_frames = []
            sorted_frames = sorted(os.listdir(os.path.join(base_dir, mode, scenario, vehicle)), key=lambda x: int(re.search(r'\d+', x).group()))
            for frame in sorted_frames:
                if frame.endswith(".yaml"):
                    with open(os.path.join(base_dir, mode, scenario, vehicle, frame), "r") as f:
                        calib = yaml.load(f, Loader=yaml.Loader)
                    c2w_matrix = get_c2w_matrix(calib)
                    resulted_frames.append({
                        "idx": int(frame.replace(".yaml", "")),
                        "lidar2world": c2w_matrix.tolist()
                    })
            
            json_dict = {
                "frames": resulted_frames
            }
            json_path = os.path.join(base_dir, mode_transform, scenario, f"transforms_{scenario}_{vehicle}.json")
            with open(json_path, "w") as f:
                json.dump(json_dict, f, indent=2)
                print(f"Saved {json_path}")
    print(f"Processed scene {scenario}")
print("Done")
# Out:
# Saved data/opv2v/test_transform/2021_08_23_16_06_26/transforms_2021_08_23_16_06_26_243.json
# Saved data/opv2v/test_transform/2021_08_23_16_06_26/transforms_2021_08_23_16_06_26_252.json
# Saved data/opv2v/test_transform/2021_08_23_16_06_26/transforms_2021_08_23_16_06_26_261.json
# Processed scene 2021_08_23_16_06_26
# Saved data/opv2v/test_transform/2021_08_23_21_47_19/transforms_2021_08_23_21_47_19_225.json
# Saved data/opv2v/test_transform/2021_08_23_21_47_19/transforms_2021_08_23_21_47_19_243.json
# Saved data/opv2v/test_transform/2021_08_23_21_47_19/transforms_2021_08_23_21_47_19_234.json
# Processed scene 2021_08_23_21_47_19
# Saved data/opv2v/test_transform/2021_08_23_15_19_19/transforms_2021_08_23_15_19_19_8690.json
# Saved data/opv2v/test_transform/2021_08_23_15_19_19/transforms_2021_08_23_15_19_19_8699.json
# Processed scene 2021_08_23_15_19_19
# Saved data/opv2v/test_transform/2021_08_20_21_10_24/transforms_2021_08_20_21_10_24_2014.json
# Saved data/opv2v/test_transform/2021_08_20_21_10_24/transforms_2021_08_20_21_10_24_1996.json
# Saved data/opv2v/test_transform/2021_08_20_21_10_24/transforms_2021_08_20_21_10_24_2005.json
# Processed scene 2021_08_20_21_10_24
# Saved data/opv2v/test_transform/2021_08_23_21_07_10/transforms_2021_08_23_21_07_10_169.json
# Saved data/opv2v/test_transform/2021_08_23_21_07_10/transforms_2021_08_23_21_07_10_160.json
# Saved data/opv2v/test_transform/2021_08_23_21_07_10/transforms_2021_08_23_21_07_10_178.json
# Processed scene 2021_08_23_21_07_10
# Saved data/opv2v/test_transform/2021_08_24_20_09_18/transforms_2021_08_24_20_09_18_3183.json
# Saved data/opv2v/test_transform/2021_08_24_20_09_18/transforms_2021_08_24_20_09_18_3174.json
# Processed scene 2021_08_24_20_09_18
# Saved data/opv2v/test_transform/2021_08_24_11_37_54/transforms_2021_08_24_11_37_54_319.json
# Saved data/opv2v/test_transform/2021_08_24_11_37_54/transforms_2021_08_24_11_37_54_301.json
# Saved data/opv2v/test_transform/2021_08_24_11_37_54/transforms_2021_08_24_11_37_54_310.json
# Processed scene 2021_08_24_11_37_54
# Saved data/opv2v/test_transform/2021_08_23_17_22_47/transforms_2021_08_23_17_22_47_592.json
# Saved data/opv2v/test_transform/2021_08_23_17_22_47/transforms_2021_08_23_17_22_47_574.json
# Saved data/opv2v/test_transform/2021_08_23_17_22_47/transforms_2021_08_23_17_22_47_583.json
# Processed scene 2021_08_23_17_22_47
# Saved data/opv2v/test_transform/2021_08_23_12_58_19/transforms_2021_08_23_12_58_19_357.json
# Saved data/opv2v/test_transform/2021_08_23_12_58_19/transforms_2021_08_23_12_58_19_366.json
# Processed scene 2021_08_23_12_58_19
# Saved data/opv2v/test_transform/2021_08_22_21_41_24/transforms_2021_08_22_21_41_24_904.json
# Saved data/opv2v/test_transform/2021_08_22_21_41_24/transforms_2021_08_22_21_41_24_895.json
# Saved data/opv2v/test_transform/2021_08_22_21_41_24/transforms_2021_08_22_21_41_24_886.json
# Processed scene 2021_08_22_21_41_24
# Saved data/opv2v/test_transform/2021_08_21_09_28_12/transforms_2021_08_21_09_28_12_641.json
# Saved data/opv2v/test_transform/2021_08_21_09_28_12/transforms_2021_08_21_09_28_12_623.json
# Saved data/opv2v/test_transform/2021_08_21_09_28_12/transforms_2021_08_21_09_28_12_632.json
# Processed scene 2021_08_21_09_28_12
# Saved data/opv2v/test_transform/2021_08_22_07_52_02/transforms_2021_08_22_07_52_02_3477.json
# Saved data/opv2v/test_transform/2021_08_22_07_52_02/transforms_2021_08_22_07_52_02_3495.json
# Saved data/opv2v/test_transform/2021_08_22_07_52_02/transforms_2021_08_22_07_52_02_3513.json
# Saved data/opv2v/test_transform/2021_08_22_07_52_02/transforms_2021_08_22_07_52_02_3504.json
# Saved data/opv2v/test_transform/2021_08_22_07_52_02/transforms_2021_08_22_07_52_02_3486.json
# Processed scene 2021_08_22_07_52_02
# Saved data/opv2v/test_transform/2021_08_18_19_48_05/transforms_2021_08_18_19_48_05_1045.json
# Saved data/opv2v/test_transform/2021_08_18_19_48_05/transforms_2021_08_18_19_48_05_1054.json
# Processed scene 2021_08_18_19_48_05
# Saved data/opv2v/test_transform/2021_08_24_07_45_41/transforms_2021_08_24_07_45_41_121.json
# Saved data/opv2v/test_transform/2021_08_24_07_45_41/transforms_2021_08_24_07_45_41_139.json
# Saved data/opv2v/test_transform/2021_08_24_07_45_41/transforms_2021_08_24_07_45_41_130.json
# Saved data/opv2v/test_transform/2021_08_24_07_45_41/transforms_2021_08_24_07_45_41_148.json
# Processed scene 2021_08_24_07_45_41
# Saved data/opv2v/test_transform/2021_08_24_20_49_54/transforms_2021_08_24_20_49_54_207.json
# Saved data/opv2v/test_transform/2021_08_24_20_49_54/transforms_2021_08_24_20_49_54_216.json
# Processed scene 2021_08_24_20_49_54
# Saved data/opv2v/test_transform/2021_08_22_09_08_29/transforms_2021_08_22_09_08_29_5942.json
# Saved data/opv2v/test_transform/2021_08_22_09_08_29/transforms_2021_08_22_09_08_29_5933.json
# Processed scene 2021_08_22_09_08_29
# Done
